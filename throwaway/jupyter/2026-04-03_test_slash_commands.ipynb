# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pyderivehelper import set_log_level, wnlc

set_log_level('DEBUG')

# %%
wnlc('   /code /tex /mathjax /run /report /help d/dx cos(x)')
# Out:
# INFO:pyderivehelper.wltools:Logger level: DEBUG
# INFO:pyderivehelper.wltools:Found slash command(s): code, tex, mathjax, run, report, help
# INFO:pyderivehelper.wltools:Executing /code pipeline...
# INFO:pyderivehelper.wltools:Generating Wolfram Language code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Sanitizing generated code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Validating code...
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel writes commands to socket: <Socket: uri=tcp://127.0.0.1:51436>
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel receives evaluated expressions from socket: <Socket: uri=tcp://127.0.0.1:51437>
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel process started with PID: 61832
# ...

# %%
wnlc(' /code d/dy y^3')
# Out:
# INFO:pyderivehelper.wltools:Logger level: DEBUG
# INFO:pyderivehelper.wltools:Found slash command(s): code
# INFO:pyderivehelper.wltools:Executing /code pipeline...
# INFO:pyderivehelper.wltools:Generating Wolfram Language code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Sanitizing generated code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Validating code...
# **Generated Wolfram Code**:
# ```wolfram
# FullSimplify[D[y^3, y]]
# ```

# %%
wnlc('/code /invalid d/dz e^(c*z)')
# Out:
# INFO:pyderivehelper.wltools:Logger level: DEBUG
# ERROR:pyderivehelper.wltools:Unknown slash command /invalid. Any subsequent slash commands were ignored.
# INFO:pyderivehelper.wltools:Found slash command(s): code
# INFO:pyderivehelper.wltools:Executing /code pipeline...
# INFO:pyderivehelper.wltools:Generating Wolfram Language code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Sanitizing generated code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Validating code...
# **Generated Wolfram Code**:
# ```wolfram
# FullSimplify[D[Exp[c z], z]]
# ```

# %%
wnlc('/code sin(2pi) + cos(2pi) + tan(2pi)')
# Out:
# INFO:pyderivehelper.wltools:Logger level: DEBUG
# INFO:pyderivehelper.wltools:Found slash command(s): code
# INFO:pyderivehelper.wltools:Executing /code pipeline...
# INFO:pyderivehelper.wltools:Generating Wolfram Language code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Sanitizing generated code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Validating code...
# **Generated Wolfram Code**:
# ```wolfram
# FullSimplify[Sin[2 Pi] + Cos[2 Pi] + Tan[2 Pi]]
# ```

# %%
wnlc('/tex sum from n= 1 to infinity of 1/n^2')
# Out:
# INFO:pyderivehelper.wltools:Logger level: DEBUG
# INFO:pyderivehelper.wltools:Found slash command(s): tex
# INFO:pyderivehelper.wltools:Executing /tex pipeline...
# INFO:pyderivehelper.wltools:Generating TeX code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Validating TeX code...
# **Generated TeX**:
# ```tex
# \sum_{n=1}^{\infty}\frac{1}{n^2}
# ```
