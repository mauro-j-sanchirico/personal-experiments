# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pyderivehelper import set_log_level, wnlc

set_log_level('DEBUG')

# %%
wnlc('/code /tex /mathjax /quiet /run /report /help d/dx cos(x)')
# Out:
# INFO:pyderivehelper.wltools:Logger level: DEBUG
# INFO:pyderivehelper.wltools:Found slash command(s): code, tex, mathjax
# INFO:pyderivehelper.wltools:Generating Wolfram Language code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Sanitizing generated code...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# INFO:pyderivehelper.wltools:Checking syntax...
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel writes commands to socket: <Socket: uri=tcp://127.0.0.1:56716>
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel receives evaluated expressions from socket: <Socket: uri=tcp://127.0.0.1:56717>
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel process started with PID: 86792
# INFO:wolframclient.evaluation.kernel.kernelcontroller:Kernel 86792 is ready. Startup took 3.16 seconds.
# **Generated Wolfram Code**:
# ```wolfram
# ...
