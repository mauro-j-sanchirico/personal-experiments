# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pyderivehelper.wltools import wc, wnlp

# %%
wnlp('Taylor series of sin(x) to 5 terms')

# %%
wnlp('Polynomial expansion of tan(y^3) to 11 terms')

# %%
wnlp('Integrate sin^n(x) where n is a positive integer')

# %%
wnlp("""
Plot sin(x) and its Taylor series to 10 terms on the same graph for x in [-2pi, 2pi]
Make the plot black and white. Use line styles to distinguish the curves.
Do not add a legend.
""")
# Out:
# Generating Wolfram Language code...
# Sanitizing generated code...
# Checking syntax...
# **Wolfram Code**:
# ```wolfram
# Plot[{Evaluate@Sin[x], Evaluate@Normal@Series[Sin[x], {x, 0, 9}]}, {x, -2 Pi, 2 Pi}, PlotStyle -> {Directive[Black, Thick], Directive[GrayLevel[0], Dashed]}, PlotLegends -> None]
# ```
# Detected plot code. Rendering plot...
# images/sin_vs_taylor_series_plot_cnpsmrdb.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
