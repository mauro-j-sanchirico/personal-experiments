# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pyderivehelper.wltools import check_syntax, wc, wnlp

# %%
wc('1+2')
# Out:
# $\displaystyle 3$
# 3

# %%
print(check_syntax('1+2+'))
print(check_syntax('1+2'))
# Out:
# None
# True
# None
# True

# %%
wnlp('Taylor series of sin(x) to 10 terms')
# Out:
# Generating Wolfram Language code...
# **Wolfram Code**:
# ```wolfram
# Series[Sin[x], {x, 0, 9}]
# ```
# **Evaluated Result**:
# $\displaystyle x-\frac{x^3}{6}+\frac{x^5}{120}-\frac{x^7}{5040}+\frac{x^9}{362880}+O\left(x^{10}\right)$
# **Raw TeX**:
# x-\frac{x^3}{6}+\frac{x^5}{120}-\frac{x^7}{5040}+\frac{x^9}{362880}+O\left(x^{10}\right)
# ```tex
# None
# ```
# SeriesData[Global`x, 0, << 2 >>, 10, 1]

# %%
wnlp('Polynomial expansion of tan(y^3) to 11 terms')
# Out:
# Generating Wolfram Language code...
# **Wolfram Code**:
# ```wolfram
# Normal@Series[Tan[y^3], {y, 0, 33}]
# ```
# **Evaluated Result**:
# $\displaystyle \frac{1382 y^{33}}{155925}+\frac{62 y^{27}}{2835}+\frac{17 y^{21}}{315}+\frac{2 y^{15}}{15}+\frac{y^9}{3}+y^3$
# **Raw TeX**:
# \frac{1382 y^{33}}{155925}+\frac{62 y^{27}}{2835}+\frac{17 y^{21}}{315}+\frac{2 y^{15}}{15}+\frac{y^9}{3}+y^3
# ```tex
# None
# ```
# Plus[Power[Global`y, 3], Times[Rational[1, 3], Power[Global`y, 9]], << 2 >>, Times[Rational[62, 2835], Power[Global`y, 27]], Times[Rational[1382, 155925], Power[Global`y, 33]]]

# %%
wc('hello world sin(x)')
# Out:
# $\displaystyle \text{hello} \text{world} x \sin$
# Times[Global`hello, Global`sin, Global`world, Global`x]
