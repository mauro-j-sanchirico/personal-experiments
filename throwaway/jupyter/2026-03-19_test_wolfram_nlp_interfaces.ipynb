# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pyderivehelper.wltools import wnlp

# %%
wnlp('Take the derivative of sin(x) with respect to x.')
# Out:
# Generating Wolfram Language code...
# Sanitizing generated code...
# Checking syntax...
# **Wolfram Code**:
# ```wolfram
# D[Sin[x], x]
# ```
# **Raw Evaluated Result**:
# ```plaintext
# Cos[Global`x]
# ```
# **Rendered Evaluated Result**:
# $\displaystyle \cos (x)$
# **Raw TeX**:
# ```tex
# \cos (x)
# ```
# (Cos[Global`x], '\\cos (x)')

# %%
wnlp('Take the Taylor series of sin(x) at x=0 to 10 terms.')
# Out:
# Generating Wolfram Language code...
# Sanitizing generated code...
# Checking syntax...
# **Wolfram Code**:
# ```wolfram
# Normal@Series[Sin[x], {x, 0, 9}]
# ```
# **Raw Evaluated Result**:
# ```plaintext
# Plus[Global`x, Times[Rational[-1, 6], Power[Global`x, 3]], << 1 >>, Times[Rational[-1, 5040], Power[Global`x, 7]], Times[Rational[1, 362880], Power[Global`x, 9]]]
# ```
# **Rendered Evaluated Result**:
# $\displaystyle \frac{x^9}{362880}-\frac{x^7}{5040}+\frac{x^5}{120}-\frac{x^3}{6}+x$
# **Raw TeX**:
# ```tex
# \frac{x^9}{362880}-\frac{x^7}{5040}+\frac{x^5}{120}-\frac{x^3}{6}+x
# ```
# (Plus[Global`x, Times[Rational[-1, 6], Power[Global`x, 3]], << 1 >>, Times[Rational[-1, 5040], Power[Global`x, 7]], Times[Rational[1, 362880], Power[Global`x, 9]]],
#  '\\frac{x^9}{362880}-\\frac{x^7}{5040}+\\frac{x^5}{120}-\\frac{x^3}{6}+x')

# %%
wnlp('Integrate sin^n(x) with respect to x.')
# Out:
# Generating Wolfram Language code...
# Sanitizing generated code...
# Checking syntax...
# **Wolfram Code**:
# ```wolfram
# Integrate[Sin[x]^n, x]
# ```
# **Raw Evaluated Result**:
# ```plaintext
# Times[-1, Cos[Global`x], << 1 >>, Power[Sin[Global`x], Plus[1, Global`n]], Power[Power[Sin[Global`x], 2], Times[Rational[1, 2], Plus[-1, Times[-1, Global`n]]]]]
# ```
# **Rendered Evaluated Result**:
# $\displaystyle -\cos (x) \sin ^{n+1}(x) \sin ^2(x)^{\frac{1}{2} (-n-1)} \, {}_2F_1\left(\frac{1}{2},\frac{1-n}{2};\frac{3}{2};\cos ^2(x)\right)$
# **Raw TeX**:
# ```tex
# -\cos (x) \sin ^{n+1}(x) \sin ^2(x)^{\frac{1}{2} (-n-1)} \, {}_2F_1\left(\frac{1}{2},\frac{1-n}{2};\frac{3}{2};\cos ^2(x)\right)
# ```
# (Times[-1, Cos[Global`x], << 1 >>, Power[Sin[Global`x], Plus[1, Global`n]], Power[Power[Sin[Global`x], 2], Times[Rational[1, 2], Plus[-1, Times[-1, Global`n]]]]],
# ...

# %%
wnlp("""
Plot the function sin(x) and its Taylor series approximation on the same graph for x in the range [-10, 10].
Make the plot black and white, and use different line styles for the two functions.
Do not include a legend.
""")
# Out:
# Generating Wolfram Language code...
# Sanitizing generated code...
# Checking syntax...
# **Wolfram Code**:
# ```wolfram
# Plot[{Evaluate@Sin[x], Evaluate@Normal@Series[Sin[x], {x, 0, 7}]}, {x, -10, 10}, PlotStyle -> {Directive[Black, Thick], Directive[Black, Dashed, Thick]}, PlotLegends -> None]
# ```
# Detected plot code. Rendering plot...
# images/sin_vs_taylor_series_plot_3omq322_.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
