# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

from pyderivehelper import wnlc, wc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wc("""Integrate[
  Exp[I*(k/(N + 1))*Omega] * BesselJ[0, Omega]/(omega + Omega),
  {Omega, -Infinity, Infinity}
]""")
# Out:
# $\displaystyle \int_{-\infty }^{\infty } \frac{J_0(\text{Omega}) e^{\frac{i k \text{Omega}}{N+1}}}{\omega +\text{Omega}} \, d\text{Omega}$
# Integrate[Times[Power[E, Times[Complex[0, 1], Global`k, Power[Plus[1, N], -1], Global`Omega]], Power[Plus[Global`omega, Global`Omega], -1], BesselJ[0, Global`Omega]], (Global`Omega, DirectedInfinity[-1], DirectedInfinity[1])]
